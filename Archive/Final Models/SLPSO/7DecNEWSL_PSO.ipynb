# %%
# Sample code for social learning PSO, using DEAP library
import operator
import random
import numpy as np
import math
from math import sqrt
import torch.nn as nn
import torch
import torchvision
import torchvision.transforms as transforms
import torch.nn.functional as F
import matplotlib.pyplot as plt
# !pip install deap
from deap import base
from deap import benchmarks
from deap import creator
from deap import tools

# Load Dataset
batch_size = 10000

transform   = transforms.Compose(
    [transforms.ToTensor(),
     transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))]) # Function to transform the dataset to the specified range

trainset      = torchvision.datasets.CIFAR10(root='./data', train=True,
                                        download=True, transform=transform)
trainloader   = torch.utils.data.DataLoader(trainset, batch_size=batch_size,
                                          shuffle=True, num_workers=2)
testset       = torchvision.datasets.CIFAR10(root='./data', train=False,
                                       download=True, transform=transform)
testloader    = torch.utils.data.DataLoader(testset, batch_size=batch_size,
                                         shuffle=False, num_workers=2)
classes       = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

device        = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

print("Device, ", device)

totalImages   = len(trainloader.dataset)
miniAmount    = 1000
numOfLoaders  = totalImages // miniAmount

print("Number of loaders to create: " + str(numOfLoaders)) # 10 Loaders

miniLoaders = []

for i in range(numOfLoaders):
  startIdx        = i * miniAmount
  endIdx          = (i + 1) * miniAmount if i < numOfLoaders - 1 else totalImages
  subset          = torch.utils.data.Subset(trainset, range(startIdx, endIdx))  # Creates a subset of the whole training set
  SubTrainLoader  = torch.utils.data.DataLoader(subset, batch_size=batch_size, shuffle=True, num_workers=2)

  miniLoaders.append(SubTrainLoader)

class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()

        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(64, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(128, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),

            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.Conv2d(256, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
        )

        self.classifier = nn.Sequential(
            nn.Linear(256 * 4 * 4, 1024),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(1024, 52),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(52, 10)
        )

    def forward(self, x):
        x = self.features(x)
        x = x.view(x.size(0), -1)
        x = self.classifier(x)
        return x

model         = Net()
PATH          = ('./40_epoch_32_batch_SGD_net.pth')
model.load_state_dict(torch.load(PATH))

finalLayer    = model.classifier[-1]
outerShape    = len(finalLayer.weight)
innerShape    = len(finalLayer.weight[0])
totalWeights  = outerShape * innerShape
biasCount     = len(finalLayer.bias)
paramCount    = sum(param.numel() for param in finalLayer.parameters())

criterion     = nn.CrossEntropyLoss()
nn.init.xavier_uniform(finalLayer.weight)
print("Final layer weight shape,", (finalLayer.weight).shape) # Shape that the layer requires is (10,52)
print("Final layer bias shape,", (finalLayer.bias).shape)

for param in model.parameters():
    param.requires_grad = False

populationList = finalLayer.weight.numpy()

posMinInit      = - 10
posMaxInit      = + 10
VMaxInit        = 5
VMinInit        = 0.1
dimension       = 530
interval        = 1
iterations      = 100#50*dimension
populationSize  = 100+int(dimension/10)

#variables used in SL-PSO
epsilon = dimension/100.0*0.01 # social influence of swarm centre


# function to get the mean positions of the inviduals (swarm centre)
def getcenter(pop):
    center=list()
    for j in range(dimension): # count through dimensions
        centerj = 0
        for i in pop: # for each particle
            centerj += i[j] # sum up position in dimention j
        centerj /= populationSize # Average
        center.append(centerj)
    return center


creator.create("FitnessMax", base.Fitness, weights=(1.0,)) # -1 is for minimise
creator.create("Particle", list, fitness=creator.FitnessMax, speed=list, smin=None, smax=None, best=None)
# particle rerpresented by list of 5 things
# 1. fitness of the particle,
# 2. speed of the particle which is also going to be a list,
# 3.4. limit of the speed value,
# 5. best state the particle has been in so far.

def generate(size, smin, smax):
    part = creator.Particle(random.uniform(posMinInit, posMaxInit) for _ in range(size))
    part.speed = [random.uniform(VMinInit, VMaxInit) for _ in range(size)]
    part.smin = smin #speed clamping values
    part.smax = smax
    return part



def updateParticle(part,pop,center,i):
    r1 = random.uniform(0, 1)
    r2 = random.uniform(0, 1)
    r3 = random.uniform(0, 1)

    #Randomly choose a demonstrator for particle i from any of particles 0 to i-1, the Particle i
    #updates its velocity by learning from the demonstrator and the mean position of the swarm
    demonstrator=random.choice(list(pop[0:i]))

    for j in range(dimension): # count through dimensions
        part.speed[j]=r1*part.speed[j]+r2*(demonstrator[j]-part[j])+r3*epsilon*(center[j]-part[j])
        part[j]=part[j]+part.speed[j]


def assign_weights(particle):
    particleweightsNP1 = np.array(particle)
    particleweightsNP = particleweightsNP1[:totalWeights]
    biases = np.array(particleweightsNP1[-biasCount:])
    biases = torch.from_numpy(biases).float()
    finalLayer.bias = torch.nn.Parameter(biases.float())
    reshapedWeights = particleweightsNP.reshape(outerShape,innerShape)
    torchWeights = torch.from_numpy(reshapedWeights).float()
    finalLayer.weight = torch.nn.Parameter(torchWeights.float())


# def fitness(particle):
#     assign_weights(particle)
#     correct_train = 0
#     total_train = 0
#     print("Particle")
#     for i, data in enumerate(trainloader,0):
#         model.to(device)
#         images, labels = data[0].to(device), data[1].to(device)
#         predicted=model(images)
#         loss = criterion(predicted, labels)
#         _, predictions = torch.max(predicted, 1)
#         total_train += labels.size(0)
#         correct_train += (predictions == labels).sum().item()
#         # print(f"Total train: {total_train}, Correct train: {correct_train}")

#     acc = 100*(correct_train/total_train)

#     print(f"Particle total accuracy {acc}")

#     return acc,

# def fitness(images, labels, particle):
#     assign_weights(particle)

#     model.to(device)
#     images.to(device)
#     labels.to(device)

#     predicted=model(images)

#     _, predictions = torch.max(predicted, 1)
#     total_train = labels.size(0)
#     correct_train = (predictions == labels).sum().item()
#     # print(f"Total train: {total_train}, Correct train: {correct_train}")
#     acc = 100*(correct_train/total_train)

#     print(f"Particle accuracy {acc}")

#     return acc,

def fitness(particle, miniNumber):
    assign_weights(particle)
    correct_train = 0
    total_train = 0

    for data in miniLoaders[miniNumber]:
        model.to(device)
        images, labels = data[0].to(device), data[1].to(device)
        predicted=model(images)

        _, predictions = torch.max(predicted, 1)
        total_train += labels.size(0)
        correct_train += (predictions == labels).sum().item()
        # print(f"Total train: {total_train}, Correct train: {correct_train}")
        print(f"Total train: {total_train}, Correct train: {correct_train}")
    acc = 100*(correct_train/total_train)

    print(f"Particle total accuracy {acc}")

    return acc,

toolbox = base.Toolbox()
toolbox.register("particle", generate, size=dimension, smin=-3, smax=3)
toolbox.register("population", tools.initRepeat, list, toolbox.particle)
toolbox.register("update", updateParticle)
toolbox.register("evaluate", fitness) #sphere function is built-in in DEAP

def main():
    pop = toolbox.population(n=populationSize) # Population Size
    stats = tools.Statistics(lambda ind: ind.fitness.values)
    stats.register("avg", np.mean)
    stats.register("std", np.std)
    stats.register("min", np.min)
    stats.register("max", np.max)

    #intialize the learning probabilities
    prob=[0]*populationSize
    for i  in range(len(pop)):
        prob[populationSize - i - 1] = 1 - i/(populationSize - 1)
        prob[populationSize - i - 1] = pow(prob[populationSize - i - 1], math.log(math.sqrt(math.ceil(dimension/100.0))))

    logbook = tools.Logbook()
    logbook.header = ["gen", "evals"] + stats.fields
    miniCounter = 0

    #begin main loop
    for g in range(iterations):

        for part in pop:
            part.fitness.values = toolbox.evaluate(part, miniCounter) #actually only one fitness value

        #Sort the individuals in the swarm in ascending order. i.e., particle 0 is the best
        pop.sort(key=lambda x: x.fitness, reverse=True)
        #calculate the center (mean value) of the swarm
        center = getcenter(pop)

        for i  in reversed(range(len(pop)-1)):  # start with worst particle, and go in reverse towards best
                                                # don't do element 0 (best). Hence the i+1 below.
            if random.uniform(0, 1)<prob[i+1]: #learning probability for that particle
                toolbox.update(pop[i+1],pop,center,i+1)

        # Gather all the fitnesses in one list and print the stats
        # print every interval
        if g%interval==0: # interval
            logbook.record(gen=g, evals=len(pop), **stats.compile(pop))
            print(logbook.stream)

        miniCounter += 1

        if miniCounter >= (len(miniLoaders)):
          miniCounter = 0
          print("Mini Counter reset!")

    return pop, logbook

if __name__ == "__main__":
    pop, logbook = main()
    print(logbook)
# Out:
# Requirement already satisfied: deap in /usr/local/lib/python3.10/dist-packages (1.4.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from deap) (1.23.5)
# Files already downloaded and verified
# Files already downloaded and verified
# Device,  cuda:0
# Number of loaders to create: 50
# Final layer weight shape, torch.Size([10, 52])
# Final layer bias shape, torch.Size([10])
# <ipython-input-1-c8b05d278d93>:110: UserWarning: nn.init.xavier_uniform is now deprecated in favor of nn.init.xavier_uniform_.
#   nn.init.xavier_uniform(finalLayer.weight)
# Streaming output truncated to the last 5000 lines.
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 224
# Particle total accuracy 22.400000000000002
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 177
# Particle total accuracy 17.7
# Total train: 1000, Correct train: 199
# Particle total accuracy 19.900000000000002
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 210
# Particle total accuracy 21.0
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 173
# Particle total accuracy 17.299999999999997
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 217
# Particle total accuracy 21.7
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 168
# Particle total accuracy 16.8
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 191
# Particle total accuracy 19.1
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 184
# Particle total accuracy 18.4
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 178
# Particle total accuracy 17.8
# Total train: 1000, Correct train: 198
# Particle total accuracy 19.8
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 195
# Particle total accuracy 19.5
# Total train: 1000, Correct train: 176
# Particle total accuracy 17.599999999999998
# Total train: 1000, Correct train: 174
# Particle total accuracy 17.4
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 200
# Particle total accuracy 20.0
# Total train: 1000, Correct train: 193
# Particle total accuracy 19.3
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 187
# Particle total accuracy 18.7
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 209
# Particle total accuracy 20.9
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 128
# Particle total accuracy 12.8
# Total train: 1000, Correct train: 158
# Particle total accuracy 15.8
# Total train: 1000, Correct train: 163
# Particle total accuracy 16.3
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 175
# Particle total accuracy 17.5
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 172
# Particle total accuracy 17.2
# Total train: 1000, Correct train: 155
# Particle total accuracy 15.5
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 170
# Particle total accuracy 17.0
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 158
# Particle total accuracy 15.8
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 172
# Particle total accuracy 17.2
# Total train: 1000, Correct train: 170
# Particle total accuracy 17.0
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 184
# Particle total accuracy 18.4
# Total train: 1000, Correct train: 177
# Particle total accuracy 17.7
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 185
# Particle total accuracy 18.5
# Total train: 1000, Correct train: 185
# Particle total accuracy 18.5
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 167
# Particle total accuracy 16.7
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 193
# Particle total accuracy 19.3
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 166
# Particle total accuracy 16.6
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 217
# Particle total accuracy 21.7
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 173
# Particle total accuracy 17.299999999999997
# Total train: 1000, Correct train: 165
# Particle total accuracy 16.5
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 207
# Particle total accuracy 20.7
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 140
# Particle total accuracy 14.000000000000002
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 247
# Particle total accuracy 24.7
# Total train: 1000, Correct train: 207
# Particle total accuracy 20.7
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 191
# Particle total accuracy 19.1
# Total train: 1000, Correct train: 143
# Particle total accuracy 14.299999999999999
# Total train: 1000, Correct train: 127
# Particle total accuracy 12.7
# Total train: 1000, Correct train: 179
# Particle total accuracy 17.9
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 228
# Particle total accuracy 22.8
# Total train: 1000, Correct train: 137
# Particle total accuracy 13.700000000000001
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 158
# Particle total accuracy 15.8
# Total train: 1000, Correct train: 193
# Particle total accuracy 19.3
# Total train: 1000, Correct train: 148
# Particle total accuracy 14.799999999999999
# Total train: 1000, Correct train: 158
# Particle total accuracy 15.8
# Total train: 1000, Correct train: 160
# Particle total accuracy 16.0
# Total train: 1000, Correct train: 168
# Particle total accuracy 16.8
# Total train: 1000, Correct train: 162
# Particle total accuracy 16.2
# Total train: 1000, Correct train: 147
# Particle total accuracy 14.7
# Total train: 1000, Correct train: 185
# Particle total accuracy 18.5
# Total train: 1000, Correct train: 159
# Particle total accuracy 15.9
# Total train: 1000, Correct train: 203
# Particle total accuracy 20.3
# Total train: 1000, Correct train: 129
# Particle total accuracy 12.9
# 11 	153  	19.698 	2.78606	12.7	25.9
# Total train: 1000, Correct train: 258
# Particle total accuracy 25.8
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 248
# Particle total accuracy 24.8
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 228
# Particle total accuracy 22.8
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 200
# Particle total accuracy 20.0
# Total train: 1000, Correct train: 203
# Particle total accuracy 20.3
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 228
# Particle total accuracy 22.8
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 255
# Particle total accuracy 25.5
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 207
# Particle total accuracy 20.7
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 210
# Particle total accuracy 21.0
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 247
# Particle total accuracy 24.7
# Total train: 1000, Correct train: 228
# Particle total accuracy 22.8
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 187
# Particle total accuracy 18.7
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 203
# Particle total accuracy 20.3
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 217
# Particle total accuracy 21.7
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 168
# Particle total accuracy 16.8
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 201
# Particle total accuracy 20.1
# Total train: 1000, Correct train: 183
# Particle total accuracy 18.3
# Total train: 1000, Correct train: 198
# Particle total accuracy 19.8
# Total train: 1000, Correct train: 195
# Particle total accuracy 19.5
# Total train: 1000, Correct train: 196
# Particle total accuracy 19.6
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 199
# Particle total accuracy 19.900000000000002
# Total train: 1000, Correct train: 185
# Particle total accuracy 18.5
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 172
# Particle total accuracy 17.2
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 179
# Particle total accuracy 17.9
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 185
# Particle total accuracy 18.5
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 194
# Particle total accuracy 19.400000000000002
# Total train: 1000, Correct train: 188
# Particle total accuracy 18.8
# Total train: 1000, Correct train: 162
# Particle total accuracy 16.2
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 201
# Particle total accuracy 20.1
# Total train: 1000, Correct train: 182
# Particle total accuracy 18.2
# Total train: 1000, Correct train: 178
# Particle total accuracy 17.8
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 197
# Particle total accuracy 19.7
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 174
# Particle total accuracy 17.4
# Total train: 1000, Correct train: 203
# Particle total accuracy 20.3
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 177
# Particle total accuracy 17.7
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 182
# Particle total accuracy 18.2
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 159
# Particle total accuracy 15.9
# Total train: 1000, Correct train: 190
# Particle total accuracy 19.0
# Total train: 1000, Correct train: 198
# Particle total accuracy 19.8
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 171
# Particle total accuracy 17.1
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 156
# Particle total accuracy 15.6
# Total train: 1000, Correct train: 150
# Particle total accuracy 15.0
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 175
# Particle total accuracy 17.5
# Total train: 1000, Correct train: 168
# Particle total accuracy 16.8
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 194
# Particle total accuracy 19.400000000000002
# Total train: 1000, Correct train: 184
# Particle total accuracy 18.4
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 201
# Particle total accuracy 20.1
# Total train: 1000, Correct train: 190
# Particle total accuracy 19.0
# Total train: 1000, Correct train: 180
# Particle total accuracy 18.0
# Total train: 1000, Correct train: 194
# Particle total accuracy 19.400000000000002
# Total train: 1000, Correct train: 150
# Particle total accuracy 15.0
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 141
# Particle total accuracy 14.099999999999998
# Total train: 1000, Correct train: 147
# Particle total accuracy 14.7
# Total train: 1000, Correct train: 143
# Particle total accuracy 14.299999999999999
# Total train: 1000, Correct train: 204
# Particle total accuracy 20.4
# Total train: 1000, Correct train: 163
# Particle total accuracy 16.3
# 12 	153  	20.8405	2.62747	14.1	26
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 283
# Particle total accuracy 28.299999999999997
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 248
# Particle total accuracy 24.8
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 284
# Particle total accuracy 28.4
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 234
# Particle total accuracy 23.400000000000002
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 228
# Particle total accuracy 22.8
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 255
# Particle total accuracy 25.5
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 265
# Particle total accuracy 26.5
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 234
# Particle total accuracy 23.400000000000002
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 217
# Particle total accuracy 21.7
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 207
# Particle total accuracy 20.7
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 143
# Particle total accuracy 14.299999999999999
# Total train: 1000, Correct train: 207
# Particle total accuracy 20.7
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 182
# Particle total accuracy 18.2
# Total train: 1000, Correct train: 191
# Particle total accuracy 19.1
# Total train: 1000, Correct train: 179
# Particle total accuracy 17.9
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 173
# Particle total accuracy 17.299999999999997
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 213
# Particle total accuracy 21.3
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 224
# Particle total accuracy 22.400000000000002
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 210
# Particle total accuracy 21.0
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 264
# Particle total accuracy 26.400000000000002
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 202
# Particle total accuracy 20.200000000000003
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 163
# Particle total accuracy 16.3
# Total train: 1000, Correct train: 168
# Particle total accuracy 16.8
# Total train: 1000, Correct train: 278
# Particle total accuracy 27.800000000000004
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 194
# Particle total accuracy 19.400000000000002
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 205
# Particle total accuracy 20.5
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 251
# Particle total accuracy 25.1
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 195
# Particle total accuracy 19.5
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 156
# Particle total accuracy 15.6
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 189
# Particle total accuracy 18.9
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 177
# Particle total accuracy 17.7
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 201
# Particle total accuracy 20.1
# Total train: 1000, Correct train: 255
# Particle total accuracy 25.5
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 248
# Particle total accuracy 24.8
# Total train: 1000, Correct train: 201
# Particle total accuracy 20.1
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 195
# Particle total accuracy 19.5
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 258
# Particle total accuracy 25.8
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 153
# Particle total accuracy 15.299999999999999
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 159
# Particle total accuracy 15.9
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 194
# Particle total accuracy 19.400000000000002
# Total train: 1000, Correct train: 161
# Particle total accuracy 16.1
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 174
# Particle total accuracy 17.4
# Total train: 1000, Correct train: 178
# Particle total accuracy 17.8
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 163
# Particle total accuracy 16.3
# Total train: 1000, Correct train: 160
# Particle total accuracy 16.0
# Total train: 1000, Correct train: 217
# Particle total accuracy 21.7
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 229
# Particle total accuracy 22.900000000000002
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 167
# Particle total accuracy 16.7
# 13 	153  	22.2484	2.76337	14.3	28.4
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 274
# Particle total accuracy 27.400000000000002
# Total train: 1000, Correct train: 263
# Particle total accuracy 26.3
# Total train: 1000, Correct train: 286
# Particle total accuracy 28.599999999999998
# Total train: 1000, Correct train: 289
# Particle total accuracy 28.9
# Total train: 1000, Correct train: 285
# Particle total accuracy 28.499999999999996
# Total train: 1000, Correct train: 289
# Particle total accuracy 28.9
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 270
# Particle total accuracy 27.0
# Total train: 1000, Correct train: 287
# Particle total accuracy 28.7
# Total train: 1000, Correct train: 288
# Particle total accuracy 28.799999999999997
# Total train: 1000, Correct train: 271
# Particle total accuracy 27.1
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 206
# Particle total accuracy 20.599999999999998
# Total train: 1000, Correct train: 279
# Particle total accuracy 27.900000000000002
# Total train: 1000, Correct train: 294
# Particle total accuracy 29.4
# Total train: 1000, Correct train: 268
# Particle total accuracy 26.8
# Total train: 1000, Correct train: 265
# Particle total accuracy 26.5
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 275
# Particle total accuracy 27.500000000000004
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 288
# Particle total accuracy 28.799999999999997
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 265
# Particle total accuracy 26.5
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 301
# Particle total accuracy 30.099999999999998
# Total train: 1000, Correct train: 287
# Particle total accuracy 28.7
# Total train: 1000, Correct train: 261
# Particle total accuracy 26.1
# Total train: 1000, Correct train: 274
# Particle total accuracy 27.400000000000002
# Total train: 1000, Correct train: 303
# Particle total accuracy 30.3
# Total train: 1000, Correct train: 280
# Particle total accuracy 28.000000000000004
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 300
# Particle total accuracy 30.0
# Total train: 1000, Correct train: 274
# Particle total accuracy 27.400000000000002
# Total train: 1000, Correct train: 248
# Particle total accuracy 24.8
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 258
# Particle total accuracy 25.8
# Total train: 1000, Correct train: 306
# Particle total accuracy 30.599999999999998
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 234
# Particle total accuracy 23.400000000000002
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 271
# Particle total accuracy 27.1
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 273
# Particle total accuracy 27.3
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 300
# Particle total accuracy 30.0
# Total train: 1000, Correct train: 251
# Particle total accuracy 25.1
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 223
# Particle total accuracy 22.3
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 264
# Particle total accuracy 26.400000000000002
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 221
# Particle total accuracy 22.1
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 248
# Particle total accuracy 24.8
# Total train: 1000, Correct train: 273
# Particle total accuracy 27.3
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 247
# Particle total accuracy 24.7
# Total train: 1000, Correct train: 274
# Particle total accuracy 27.400000000000002
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 200
# Particle total accuracy 20.0
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 251
# Particle total accuracy 25.1
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 214
# Particle total accuracy 21.4
# Total train: 1000, Correct train: 234
# Particle total accuracy 23.400000000000002
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 275
# Particle total accuracy 27.500000000000004
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 255
# Particle total accuracy 25.5
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 279
# Particle total accuracy 27.900000000000002
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 252
# Particle total accuracy 25.2
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 262
# Particle total accuracy 26.200000000000003
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 275
# Particle total accuracy 27.500000000000004
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 263
# Particle total accuracy 26.3
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 264
# Particle total accuracy 26.400000000000002
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 216
# Particle total accuracy 21.6
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 227
# Particle total accuracy 22.7
# Total train: 1000, Correct train: 133
# Particle total accuracy 13.3
# Total train: 1000, Correct train: 215
# Particle total accuracy 21.5
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 278
# Particle total accuracy 27.800000000000004
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 230
# Particle total accuracy 23.0
# Total train: 1000, Correct train: 258
# Particle total accuracy 25.8
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 174
# Particle total accuracy 17.4
# Total train: 1000, Correct train: 270
# Particle total accuracy 27.0
# Total train: 1000, Correct train: 169
# Particle total accuracy 16.900000000000002
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 177
# Particle total accuracy 17.7
# Total train: 1000, Correct train: 255
# Particle total accuracy 25.5
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 225
# Particle total accuracy 22.5
# Total train: 1000, Correct train: 285
# Particle total accuracy 28.499999999999996
# Total train: 1000, Correct train: 181
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 170
# Particle total accuracy 17.0
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 261
# Particle total accuracy 26.1
# Total train: 1000, Correct train: 174
# Particle total accuracy 17.4
# Total train: 1000, Correct train: 241
# Particle total accuracy 24.099999999999998
# Total train: 1000, Correct train: 191
# Particle total accuracy 19.1
# Total train: 1000, Correct train: 172
# Particle total accuracy 17.2
# Total train: 1000, Correct train: 140
# Particle total accuracy 14.000000000000002
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# 14 	153  	24.6359	3.21708	13.3	30.9
# Total train: 1000, Correct train: 290
# Particle total accuracy 28.999999999999996
# Total train: 1000, Correct train: 295
# Particle total accuracy 29.5
# Total train: 1000, Correct train: 273
# Particle total accuracy 27.3
# Total train: 1000, Correct train: 267
# Particle total accuracy 26.700000000000003
# Total train: 1000, Correct train: 263
# Particle total accuracy 26.3
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 301
# Particle total accuracy 30.099999999999998
# Total train: 1000, Correct train: 291
# Particle total accuracy 29.099999999999998
# Total train: 1000, Correct train: 282
# Particle total accuracy 28.199999999999996
# Total train: 1000, Correct train: 275
# Particle total accuracy 27.500000000000004
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 269
# Particle total accuracy 26.900000000000002
# Total train: 1000, Correct train: 259
# Particle total accuracy 25.900000000000002
# Total train: 1000, Correct train: 279
# Particle total accuracy 27.900000000000002
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 254
# Particle total accuracy 25.4
# Total train: 1000, Correct train: 265
# Particle total accuracy 26.5
# Total train: 1000, Correct train: 245
# Particle total accuracy 24.5
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 277
# Particle total accuracy 27.700000000000003
# Total train: 1000, Correct train: 219
# Particle total accuracy 21.9
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 268
# Particle total accuracy 26.8
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 239
# Particle total accuracy 23.9
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 264
# Particle total accuracy 26.400000000000002
# Total train: 1000, Correct train: 240
# Particle total accuracy 24.0
# Total train: 1000, Correct train: 252
# Particle total accuracy 25.2
# Total train: 1000, Correct train: 252
# Particle total accuracy 25.2
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 301
# Particle total accuracy 30.099999999999998
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 187
# Particle total accuracy 18.7
# Total train: 1000, Correct train: 231
# Particle total accuracy 23.1
# Total train: 1000, Correct train: 246
# Particle total accuracy 24.6
# Total train: 1000, Correct train: 262
# Particle total accuracy 26.200000000000003
# Total train: 1000, Correct train: 233
# Particle total accuracy 23.3
# Total train: 1000, Correct train: 208
# Particle total accuracy 20.8
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 304
# Particle total accuracy 30.4
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 250
# Particle total accuracy 25.0
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 231
# Particle total accuracy 23.1
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 273
# Particle total accuracy 27.3
# Total train: 1000, Correct train: 251
# Particle total accuracy 25.1
# Total train: 1000, Correct train: 247
# Particle total accuracy 24.7
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 192
# Particle total accuracy 19.2
# Total train: 1000, Correct train: 263
# Particle total accuracy 26.3
# Total train: 1000, Correct train: 258
# Particle total accuracy 25.8
# Total train: 1000, Correct train: 198
# Particle total accuracy 19.8
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 220
# Particle total accuracy 22.0
# Total train: 1000, Correct train: 288
# Particle total accuracy 28.799999999999997
# Total train: 1000, Correct train: 299
# Particle total accuracy 29.9
# Total train: 1000, Correct train: 236
# Particle total accuracy 23.599999999999998
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 268
# Particle total accuracy 26.8
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 218
# Particle total accuracy 21.8
# Total train: 1000, Correct train: 244
# Particle total accuracy 24.4
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 226
# Particle total accuracy 22.6
# Total train: 1000, Correct train: 253
# Particle total accuracy 25.3
# Total train: 1000, Correct train: 270
# Particle total accuracy 27.0
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 252
# Particle total accuracy 25.2
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# Total train: 1000, Correct train: 242
# Particle total accuracy 24.2
# Total train: 1000, Correct train: 224
# Particle total accuracy 22.400000000000002
# Total train: 1000, Correct train: 238
# Particle total accuracy 23.799999999999997
# Total train: 1000, Correct train: 222
# Particle total accuracy 22.2
# Total train: 1000, Correct train: 235
# Particle total accuracy 23.5
# Total train: 1000, Correct train: 237
# Particle total accuracy 23.7
# Total train: 1000, Correct train: 232
# Particle total accuracy 23.200000000000003
# Total train: 1000, Correct train: 211
# Particle total accuracy 21.099999999999998
# Total train: 1000, Correct train: 235
# ...
# Particle total accuracy 18.099999999999998
# Total train: 1000, Correct train: 152
# Particle total accuracy 15.2
# Total train: 1000, Correct train: 260
# Particle total accuracy 26.0
# 25 	153  	27.415 	3.11274	14.5	33.7
# Total train: 1000, Correct train: 345
# Particle total accuracy 34.5
# Total train: 1000, Correct train: 352
# Particle total accuracy 35.199999999999996
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 315
# Particle total accuracy 31.5
# Total train: 1000, Correct train: 316
# Particle total accuracy 31.6
# Total train: 1000, Correct train: 339
# Particle total accuracy 33.900000000000006
# Total train: 1000, Correct train: 316
# Particle total accuracy 31.6
# Total train: 1000, Correct train: 322
# Particle total accuracy 32.2
# Total train: 1000, Correct train: 340
# Particle total accuracy 34.0
# Total train: 1000, Correct train: 302
# Particle total accuracy 30.2
# Total train: 1000, Correct train: 325
# Particle total accuracy 32.5
# Total train: 1000, Correct train: 332
# Particle total accuracy 33.2
# Total train: 1000, Correct train: 337
# Particle total accuracy 33.7
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 355
# Particle total accuracy 35.5
# Total train: 1000, Correct train: 307
# Particle total accuracy 30.7
# Total train: 1000, Correct train: 324
# Particle total accuracy 32.4
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 349
# Particle total accuracy 34.9
# Total train: 1000, Correct train: 299
# Particle total accuracy 29.9
# Total train: 1000, Correct train: 332
# Particle total accuracy 33.2
# Total train: 1000, Correct train: 357
# Particle total accuracy 35.699999999999996
# Total train: 1000, Correct train: 316
# Particle total accuracy 31.6
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 335
# Particle total accuracy 33.5
# Total train: 1000, Correct train: 328
# Particle total accuracy 32.800000000000004
# Total train: 1000, Correct train: 299
# Particle total accuracy 29.9
# Total train: 1000, Correct train: 274
# Particle total accuracy 27.400000000000002
# Total train: 1000, Correct train: 325
# Particle total accuracy 32.5
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 310
# Particle total accuracy 31.0
# Total train: 1000, Correct train: 294
# Particle total accuracy 29.4
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 306
# Particle total accuracy 30.599999999999998
# Total train: 1000, Correct train: 324
# Particle total accuracy 32.4
# Total train: 1000, Correct train: 319
# Particle total accuracy 31.900000000000002
# Total train: 1000, Correct train: 313
# Particle total accuracy 31.3
# Total train: 1000, Correct train: 306
# Particle total accuracy 30.599999999999998
# Total train: 1000, Correct train: 327
# Particle total accuracy 32.7
# Total train: 1000, Correct train: 334
# Particle total accuracy 33.4
# Total train: 1000, Correct train: 300
# Particle total accuracy 30.0
# Total train: 1000, Correct train: 287
# Particle total accuracy 28.7
# Total train: 1000, Correct train: 311
# Particle total accuracy 31.1
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 329
# Particle total accuracy 32.9
# Total train: 1000, Correct train: 289
# Particle total accuracy 28.9
# Total train: 1000, Correct train: 301
# Particle total accuracy 30.099999999999998
# Total train: 1000, Correct train: 301
# Particle total accuracy 30.099999999999998
# Total train: 1000, Correct train: 318
# Particle total accuracy 31.8
# Total train: 1000, Correct train: 312
# Particle total accuracy 31.2
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 322
# Particle total accuracy 32.2
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 312
# Particle total accuracy 31.2
# Total train: 1000, Correct train: 266
# Particle total accuracy 26.6
# Total train: 1000, Correct train: 325
# Particle total accuracy 32.5
# Total train: 1000, Correct train: 285
# Particle total accuracy 28.499999999999996
# Total train: 1000, Correct train: 291
# Particle total accuracy 29.099999999999998
# Total train: 1000, Correct train: 290
# Particle total accuracy 28.999999999999996
# Total train: 1000, Correct train: 322
# Particle total accuracy 32.2
# Total train: 1000, Correct train: 312
# Particle total accuracy 31.2
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 293
# Particle total accuracy 29.299999999999997
# Total train: 1000, Correct train: 318
# Particle total accuracy 31.8
# Total train: 1000, Correct train: 293
# Particle total accuracy 29.299999999999997
# Total train: 1000, Correct train: 346
# Particle total accuracy 34.599999999999994
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 280
# Particle total accuracy 28.000000000000004
# Total train: 1000, Correct train: 271
# Particle total accuracy 27.1
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 281
# Particle total accuracy 28.1
# Total train: 1000, Correct train: 285
# Particle total accuracy 28.499999999999996
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 299
# Particle total accuracy 29.9
# Total train: 1000, Correct train: 291
# Particle total accuracy 29.099999999999998
# Total train: 1000, Correct train: 289
# Particle total accuracy 28.9
# Total train: 1000, Correct train: 314
# Particle total accuracy 31.4
# Total train: 1000, Correct train: 314
# Particle total accuracy 31.4
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 298
# Particle total accuracy 29.799999999999997
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 286
# Particle total accuracy 28.599999999999998
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 357
# Particle total accuracy 35.699999999999996
# Total train: 1000, Correct train: 293
# Particle total accuracy 29.299999999999997
# Total train: 1000, Correct train: 315
# Particle total accuracy 31.5
# Total train: 1000, Correct train: 313
# Particle total accuracy 31.3
# Total train: 1000, Correct train: 295
# Particle total accuracy 29.5
# Total train: 1000, Correct train: 289
# Particle total accuracy 28.9
# Total train: 1000, Correct train: 334
# Particle total accuracy 33.4
# Total train: 1000, Correct train: 328
# Particle total accuracy 32.800000000000004
# Total train: 1000, Correct train: 314
# Particle total accuracy 31.4
# Total train: 1000, Correct train: 272
# Particle total accuracy 27.200000000000003
# Total train: 1000, Correct train: 298
# Particle total accuracy 29.799999999999997
# Total train: 1000, Correct train: 311
# Particle total accuracy 31.1
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 324
# Particle total accuracy 32.4
# Total train: 1000, Correct train: 336
# Particle total accuracy 33.6
# Total train: 1000, Correct train: 303
# Particle total accuracy 30.3
# Total train: 1000, Correct train: 275
# Particle total accuracy 27.500000000000004
# Total train: 1000, Correct train: 303
# Particle total accuracy 30.3
# Total train: 1000, Correct train: 297
# Particle total accuracy 29.7
# Total train: 1000, Correct train: 298
# Particle total accuracy 29.799999999999997
# Total train: 1000, Correct train: 296
# Particle total accuracy 29.599999999999998
# Total train: 1000, Correct train: 295
# Particle total accuracy 29.5
# Total train: 1000, Correct train: 297
# Particle total accuracy 29.7
# Total train: 1000, Correct train: 298
# Particle total accuracy 29.799999999999997
# Total train: 1000, Correct train: 290
# Particle total accuracy 28.999999999999996
# Total train: 1000, Correct train: 288
# Particle total accuracy 28.799999999999997
# Total train: 1000, Correct train: 281
# Particle total accuracy 28.1
# Total train: 1000, Correct train: 287
# Particle total accuracy 28.7
# Total train: 1000, Correct train: 316
# Particle total accuracy 31.6
# Total train: 1000, Correct train: 268
# Particle total accuracy 26.8
# Total train: 1000, Correct train: 300
# Particle total accuracy 30.0
# Total train: 1000, Correct train: 328
# Particle total accuracy 32.800000000000004
# Total train: 1000, Correct train: 278
# Particle total accuracy 27.800000000000004
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 281
# Particle total accuracy 28.1
# Total train: 1000, Correct train: 270
# Particle total accuracy 27.0
# Total train: 1000, Correct train: 276
# Particle total accuracy 27.6
# Total train: 1000, Correct train: 268
# Particle total accuracy 26.8
# Total train: 1000, Correct train: 353
# Particle total accuracy 35.3
# Total train: 1000, Correct train: 295
# Particle total accuracy 29.5
# Total train: 1000, Correct train: 294
# Particle total accuracy 29.4
# Total train: 1000, Correct train: 283
# Particle total accuracy 28.299999999999997
# Total train: 1000, Correct train: 283
# Particle total accuracy 28.299999999999997
# Total train: 1000, Correct train: 281
# Particle total accuracy 28.1
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 281
# Particle total accuracy 28.1
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 212
# Particle total accuracy 21.2
# Total train: 1000, Correct train: 295
# Particle total accuracy 29.5
# Total train: 1000, Correct train: 234
# Particle total accuracy 23.400000000000002
# Total train: 1000, Correct train: 243
# Particle total accuracy 24.3
# Total train: 1000, Correct train: 302
# Particle total accuracy 30.2
# Total train: 1000, Correct train: 307
# Particle total accuracy 30.7
# Total train: 1000, Correct train: 264
# Particle total accuracy 26.400000000000002
# Total train: 1000, Correct train: 256
# Particle total accuracy 25.6
# Total train: 1000, Correct train: 252
# Particle total accuracy 25.2
# Total train: 1000, Correct train: 313
# Particle total accuracy 31.3
# Total train: 1000, Correct train: 270
# Particle total accuracy 27.0
# Total train: 1000, Correct train: 257
# Particle total accuracy 25.7
# Total train: 1000, Correct train: 249
# Particle total accuracy 24.9
# Total train: 1000, Correct train: 276
# Particle total accuracy 27.6
# Total train: 1000, Correct train: 165
# Particle total accuracy 16.5
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 186
# Particle total accuracy 18.6
# 26 	153  	30.1327	2.91502	16.5	35.7
# Total train: 1000, Correct train: 344
# Particle total accuracy 34.4
# Total train: 1000, Correct train: 337
# Particle total accuracy 33.7
# Total train: 1000, Correct train: 365
# Particle total accuracy 36.5
# Total train: 1000, Correct train: 373
# Particle total accuracy 37.3
# Total train: 1000, Correct train: 330
# Particle total accuracy 33.0
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 345
# Particle total accuracy 34.5
# Total train: 1000, Correct train: 339
# Particle total accuracy 33.900000000000006
# Total train: 1000, Correct train: 388
# Particle total accuracy 38.800000000000004
# Total train: 1000, Correct train: 340
# Particle total accuracy 34.0
# Total train: 1000, Correct train: 353
# Particle total accuracy 35.3
# Total train: 1000, Correct train: 350
# Particle total accuracy 35.0
# Total train: 1000, Correct train: 339
# Particle total accuracy 33.900000000000006
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 315
# Particle total accuracy 31.5
# Total train: 1000, Correct train: 339
# Particle total accuracy 33.900000000000006
# Total train: 1000, Correct train: 333
# Particle total accuracy 33.300000000000004
# Total train: 1000, Correct train: 293
# Particle total accuracy 29.299999999999997
# Total train: 1000, Correct train: 351
# Particle total accuracy 35.099999999999994
# Total train: 1000, Correct train: 336
# Particle total accuracy 33.6
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 327
# Particle total accuracy 32.7
# Total train: 1000, Correct train: 313
# Particle total accuracy 31.3
# Total train: 1000, Correct train: 292
# Particle total accuracy 29.2
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 339
# Particle total accuracy 33.900000000000006
# Total train: 1000, Correct train: 330
# Particle total accuracy 33.0
# Total train: 1000, Correct train: 363
# Particle total accuracy 36.3
# Total train: 1000, Correct train: 337
# Particle total accuracy 33.7
# Total train: 1000, Correct train: 345
# Particle total accuracy 34.5
# Total train: 1000, Correct train: 313
# Particle total accuracy 31.3
# Total train: 1000, Correct train: 338
# Particle total accuracy 33.800000000000004
# Total train: 1000, Correct train: 324
# Particle total accuracy 32.4
# Total train: 1000, Correct train: 334
# Particle total accuracy 33.4
# Total train: 1000, Correct train: 309
# Particle total accuracy 30.9
# Total train: 1000, Correct train: 334
# Particle total accuracy 33.4
# Total train: 1000, Correct train: 305
# Particle total accuracy 30.5
# Total train: 1000, Correct train: 325
# Particle total accuracy 32.5
# Total train: 1000, Correct train: 346
# Particle total accuracy 34.599999999999994
# Total train: 1000, Correct train: 340
# Particle total accuracy 34.0
# Total train: 1000, Correct train: 262
# Particle total accuracy 26.200000000000003
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
# Total train: 1000, Correct train: 329
# Particle total accuracy 32.9
# Total train: 1000, Correct train: 321
# Particle total accuracy 32.1
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 314
# Particle total accuracy 31.4
# Total train: 1000, Correct train: 354
# Particle total accuracy 35.4
# Total train: 1000, Correct train: 346
# Particle total accuracy 34.599999999999994
# Total train: 1000, Correct train: 317
# Particle total accuracy 31.7
# Total train: 1000, Correct train: 311
# Particle total accuracy 31.1
# Total train: 1000, Correct train: 331
# Particle total accuracy 33.1
# Total train: 1000, Correct train: 310
# Particle total accuracy 31.0
# Total train: 1000, Correct train: 308
# Particle total accuracy 30.8
# Total train: 1000, Correct train: 329
# Particle total accuracy 32.9
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 338
# Particle total accuracy 33.800000000000004
# Total train: 1000, Correct train: 314
# Particle total accuracy 31.4
# Total train: 1000, Correct train: 319
# Particle total accuracy 31.900000000000002
# Total train: 1000, Correct train: 328
# Particle total accuracy 32.800000000000004
# Total train: 1000, Correct train: 303
# Particle total accuracy 30.3
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 358
# Particle total accuracy 35.8
# Total train: 1000, Correct train: 332
# Particle total accuracy 33.2
# Total train: 1000, Correct train: 338
# Particle total accuracy 33.800000000000004
# Total train: 1000, Correct train: 320
# Particle total accuracy 32.0
# Total train: 1000, Correct train: 304
# Particle total accuracy 30.4
# Total train: 1000, Correct train: 350
# Particle total accuracy 35.0
# Total train: 1000, Correct train: 323
# Particle total accuracy 32.300000000000004
